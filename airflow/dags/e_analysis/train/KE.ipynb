# %%
# !pip install pykeen -q

# %%
from pykeen.pipeline import pipeline

# %%
import torch

# %%
from pykeen.pipeline import pipeline
from pykeen.triples import TriplesFactory

tf = TriplesFactory.from_path(
    path="/content/resultss.tsv",
)

training, testing = tf.split(random_state=42)
print(f"Entities: {len(tf.entity_to_id)}, Relations: {len(tf.relation_to_id)}")

# Run full pipeline: splits, trains, saves config & model
results = pipeline(
    training=training,
    testing=testing,
    model='TransH',
    training_kwargs=dict(num_epochs=30, batch_size=2048, use_tqdm_batch=True),
    evaluation_kwargs = {"batch_size": 4096},
    model_kwargs= {
        "embedding_dim": 64,     # Reduced dimension for speed
    },
    optimizer='Adam',
    optimizer_kwargs=dict(lr=1e-3),
    random_seed=42,
    device='cuda'  # or 'cpu'
)

# Persist for later
results.save_to_directory("/content/pykeen_runs/transh_run")
# Out:
# INFO:pykeen.triples.splitting:done splitting triples to groups of sizes [561580, 250240]
# INFO:pykeen.pipeline.api:Using device: cuda
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Entities: 439389, Relations: 18
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Training epochs on cuda:0:   0%|          | 0/30 [00:00<?, ?epoch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Training batches on cuda:0:   0%|          | 0.00/489 [00:00<?, ?batch/s]
# Evaluating on cuda:0:   0%|          | 0.00/250k [00:00<?, ?triple/s]
# INFO:pykeen.evaluation.evaluator:Evaluation took 3823.70s seconds
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=439389, num_relations=18, create_inverse_triples=False, num_triples=1000959, path="/content/resultss.tsv") to file:///content/pykeen_runs/transh_run/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /content/pykeen_runs/transh_run

# %%
results.save_to_directory("/content/pykeen_runs/good_run")
# Out:
# INFO:pykeen.triples.triples_factory:Stored TriplesFactory(num_entities=439389, num_relations=18, create_inverse_triples=False, num_triples=1000959, path="/content/resultss.tsv") to file:///content/pykeen_runs/good_run/training_triples
# INFO:pykeen.pipeline.api:Saved to directory: /content/pykeen_runs/good_run

# %%
results.metric_results.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-94ddc2d6a96a> in <cell line: 0>()
# ----> 1 results.metric_results.to_dataframe()
#
# NameError: name 'results' is not defined
